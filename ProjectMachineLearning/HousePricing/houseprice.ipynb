# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Dataset/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.price,df.bedrooms, label = 'bedrooms')
plt.scatter(df.price,df.bathrooms, label = 'bathrooms')
plt.xlabel("Price ($)")
plt.xticks(rotation = 45)
plt.title("Price Between Bathrooms and Bedrooms")
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.scatter(df.price, df.grade, label = "Grade")
plt.scatter(df.price, df.condition, label = "Condition")
plt.scatter(df.price, df.waterfront, label = "Waterfront")
plt.scatter(df.price, df.view, label = "View")
plt.xticks(rotation = 45)
plt.legend(loc = "upper right")
plt.title("Price VS Quality House")
plt.xlabel("Price ($)")
plt.show()

# %%
df.corr().style.background_gradient(cmap ="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_0c507706_d951_11e9_a009_086266d056e0row0_col0 {
#             background-color:  #b40426;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col1 {
#             background-color:  #445acc;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col2 {
#             background-color:  #6485ec;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col3 {
#             background-color:  #7295f4;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col4 {
#             background-color:  #6b8df0;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col6 {
#             background-color:  #84a7fc;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col7 {
#             background-color:  #455cce;
#         }    #T_0c507706_d951_11e9_a009_086266d056e0row0_col8 {
#             background-color:  #5470de;
# ...

# %%
Y = df.price.values
X = df.drop(['price','id','date'], axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 10)

# %%
print ('Data Train =', X_train.shape[0] ,  'Data Test =' , X_test.shape[0])
# Out:
# Data Train = 17290 Data Test = 4323

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Y_predict = regr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_predict,Y_test)
# Out:
# 0.5292733234594114
